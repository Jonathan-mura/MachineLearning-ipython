# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import *

# %%
e = np.eye(3)

# %%
plt.imshow(e)

# %%
a = np.arange(20)

# %%
plt.plot(a,a**2)
